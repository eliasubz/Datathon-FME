# %% [markdown]
# EDA

# %% [markdown]
# #### load data

# %%
# Out:
#       ID  id_season       aggregated_family       family  \
# 0  11628         87                T-shirts      T-shirt
# 1   4200         88        Coats and Parkas  Trenchcoats
# 2   8658         89  Sweaters and Cardigans      Sweater
# 3   2005         88   Dresses and jumpsuits      Dresses
# 4   5550         88     Jackets and Blazers      Blazers
#
#                               category    fabric   color_name    color_rgb  \
# 0                                 Tops  CIRCULAR       FUCSIA   229,53,129
# 1                            Outerwear     WOVEN        BEIGE  225,204,175
# 2                                 Tops    TRICOT    ANTRACITA     56,62,57
# 3  Dresses, jumpsuits and Complete set  CIRCULAR        NEGRO        0,0,0
# 4                            Outerwear     WOVEN  ROSA PASTEL  224,198,198
#
#                                      image_embedding length_type  ...  \
# 0  0.060357273,-0.088701785,0.9783404,-0.77027303...    Standard  ...
# ...

# %%
import pandas as pd
date_cols = ["phase_in", "phase_out"]

# Load data
train = pd.read_csv("../data/train_subset.csv", delimiter=';', parse_dates=date_cols,
    infer_datetime_format=True,)
test = pd.read_csv("../data/test_subset.csv", delimiter=';', parse_dates=date_cols,
    infer_datetime_format=True,)
# Out:
# C:\Users\elias\AppData\Local\Temp\ipykernel_11408\1507468280.py:5: FutureWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   train = pd.read_csv("../data/train_subset.csv", delimiter=';', parse_dates=date_cols,
# C:\Users\elias\AppData\Local\Temp\ipykernel_11408\1507468280.py:5: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   train = pd.read_csv("../data/train_subset.csv", delimiter=';', parse_dates=date_cols,
# ...

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 33 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   ID                  2000 non-null   int64
#  1   id_season           2000 non-null   int64
#  2   aggregated_family   2000 non-null   object
#  3   family              2000 non-null   object
#  4   category            2000 non-null   object
#  5   fabric              2000 non-null   object
#  6   color_name          2000 non-null   object
#  7   color_rgb           2000 non-null   object
#  8   image_embedding     2000 non-null   object
#  9   length_type         1831 non-null   object
#  10  silhouette_type     1739 non-null   object
#  11  waist_type          492 non-null    object
#  12  neck_lapel_type     1229 non-null   object
#  13  sleeve_length_type  1192 non-null   object
#  14  heel_shape_type     0 non-null      float64
# ...

# %%
train.head()
# Out:
#       ID  id_season       aggregated_family       family  \
# 0  11628         87                T-shirts      T-shirt
# 1   4200         88        Coats and Parkas  Trenchcoats
# 2   8658         89  Sweaters and Cardigans      Sweater
# 3   2005         88   Dresses and jumpsuits      Dresses
# 4   5550         88     Jackets and Blazers      Blazers
#
#                               category    fabric   color_name    color_rgb  \
# 0                                 Tops  CIRCULAR       FUCSIA   229,53,129
# 1                            Outerwear     WOVEN        BEIGE  225,204,175
# 2                                 Tops    TRICOT    ANTRACITA     56,62,57
# 3  Dresses, jumpsuits and Complete set  CIRCULAR        NEGRO        0,0,0
# 4                            Outerwear     WOVEN  ROSA PASTEL  224,198,198
#
#                                      image_embedding length_type  ...  \
# 0  0.060357273,-0.088701785,0.9783404,-0.77027303...    Standard  ...
# ...

# %%
import matplotlib.pyplot as plt

a = 3
import pandas as pd
import numpy as np
from pathlib import Path
import joblib

from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_log_error
from sklearn.model_selection import train_test_split

# from xgboost import XGBRegressor

from warnings import simplefilter
simplefilter("ignore")

print("=== SHAPE ===")
print("Train:", train.shape)
# print("Test:", test.shape)

print("\n=== HEAD (Train) ===")
print(train.head())

print("\n=== INFO (Train) ===")
print(train.info())

print("\n=== MISSING VALUES (Train) ===")
print(train.isnull().sum())

print("\n=== BASIC STATISTICS (Train) ===")
print(train.describe())

# If target column exists, print its distribution (replace 'target' with correct column)
# train['target'].value_counts().plot(kind='bar')
# plt.title("Target Distribution")
# plt.show()
import seaborn as sns

# Select only numeric columns
numeric_cols = train.select_dtypes(include=["int64", "float64"])
print("dtypes: ",train.dtypes)

# Correlation heatmap
plt.figure(figsize=(10,6))
sns.heatmap(numeric_cols.corr(), annot=False, cmap="viridis")
plt.title("Correlation Heatmap")
plt.show()

# Histograms for each numeric column
numeric_cols.hist(bins=30, figsize=(12,10))
plt.tight_layout()
plt.show()
# Out:
# C:\Users\elias\AppData\Local\Temp\ipykernel_11408\3939049768.py:7: FutureWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   train = pd.read_csv("../data/train_subset.csv", delimiter=';', parse_dates=date_cols,
# C:\Users\elias\AppData\Local\Temp\ipykernel_11408\3939049768.py:7: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   train = pd.read_csv("../data/train_subset.csv", delimiter=';', parse_dates=date_cols,
# ...

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 33 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   ID                  2000 non-null   int64
#  1   id_season           2000 non-null   int64
#  2   aggregated_family   2000 non-null   object
#  3   family              2000 non-null   object
#  4   category            2000 non-null   object
#  5   fabric              2000 non-null   object
#  6   color_name          2000 non-null   object
#  7   color_rgb           2000 non-null   object
#  8   image_embedding     2000 non-null   object
#  9   length_type         1831 non-null   object
#  10  silhouette_type     1739 non-null   object
#  11  waist_type          492 non-null    object
#  12  neck_lapel_type     1229 non-null   object
#  13  sleeve_length_type  1192 non-null   object
#  14  heel_shape_type     0 non-null      float64
# ...
